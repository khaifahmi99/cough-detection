# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %matplotlib inline

# %%
original_vids = os.listdir('unprocessed')
original_vids = sorted(original_vids)
print(len(original_vids))
# Out:
# 234

# %%
person_list = []
for vid in original_vids:
    name = vid.split('_')
    person_list.append(name[0])

person_list = sorted(list(set(person_list)))
person_list
# Out:
# ['S001',
#  'S002',
#  'S003',
#  'S004',
#  'S005',
#  'S006',
#  'S007',
#  'S008',
#  'S009',
#  'S010',
#  'S011',
#  'S012',
#  'S013',
#  'S014',
#  'S015',
#  'S016',
#  'S017',
#  'S018',
#  'S019',
#  'S020']

# %%
from shutil import copyfile

for per in person_list:
    count = 1
    for vid in original_vids:
        if per in vid:
            version = '{0:03}'.format(count)
            copyfile('./unprocessed/' + vid, './dataset/' + per + '_v' + version + '.avi')
            count+=1
            
print(len(os.listdir('./dataset/')))
# Out:
# 001
# 002
# 003
# 004
# 005
# 006
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 235
